# %% [markdown]
# # TF-IDF based Recommender System
#
# ### Recommender System based on tf-idf as vector representation of documents

# %% [markdown]
# ## 1. Importing Libraries
#
# Importing libraries that using for reading file, tf-idf calculation, cosine similarity calculation

# %%
import pandas as pd
import pickle as pk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
from nltk.stem.snowball import SnowballStemmer
import nltk
import numpy
stemmer = SnowballStemmer("english")

# %% [markdown]
# ## 2. Reading input dataset
#
# Reading the csv file to get the Article id, Title and News Content

# %%
INPUT_FILE_PATH = 'IBTdataset1.csv'

# %%
inputfile = pd.read_csv(INPUT_FILE_PATH)

# %%
#Selecting contents and removing rows having na's
inputfile1 = inputfile[['Article_Id','Title','Content']].dropna()
# Out:
#       Article_Id                                              Title  \
# 0              0  14 dead after bus falls into canal in Telangan...
# 1              1  Pratibha Tiwari molested on busy road   Saath ...
# 2              2  US  South Korea begin joint military drill ami...
# 3              3  Illegal construction in Bengaluru  Will my hou...
# 4              4  Punjab Gau Rakshak Dal chief held for assaulti...
# 5              5  Phillipines drug war  1 800 drug-related death...
# 6              6  Infosys shares likely to fall on Tuesday after...
# 7              7  Dialogue crucial in finding permanent solution...
# 8              8  School bus overturns in Jammu killing 1 and in...
# 9              9  Rajasthan  Villagers rescue 50 kids after scho...
# 10            10  Karnataka bus accident  8 schoolchildren dead ...
# 11            11  Meghalaya accident  At least 30 killed and 8 i...
# 12            12  Tamil Nadu  2 students dead  over 40 injured a...
# 13            13  Uttarakhand  12 dead as bus falls into a gorge...
# 14            14  42 missing in Mahad bridge collapse  Met says ...
# 15            15  Mumbai-Goa bridge collapse  Two bodies recover...
# 16            16  Mumbai-Goa bridge collapse  Death toll rises t...
# 17            17  Mumbai-Goa bridge collapse  What we know so fa...
# 18            18  Maharashtra  4 from Pune killed  1 injured in ...
# 19            19  Uttar Pradesh  7 children dead after van hits ...
# 20            20  Maharashtra  7-month-old baby survives Bhiwand...
# 21            21  Madhya Pradesh  5 dead  10 injured in truck-je...
# 22            22         26 killed after bus catches fire in Taiwan
# 23            23  Jaipur  3 killed  5 injured as MLA s son alleg...
# 24            24  Fire Breaks Out At Maharashtra Secretariat Com...
# 25            25     18-Year-Old Killed in Mumbai Building Collapse
# 26            26  Forensic Report Rules Out Sabotage As Cause Be...
# 27            27   Star Trek  actor Anton Yelchin dead in fatal ...
# 28            28  Multilingual actress Pranitha escapes road acc...
# 29            29  Mumbai-Pune Expressway accident kills 17  inju...
# ...          ...                                                ...
# 4801        4801  India s rank goes up 12 notches in World Bank ...
# 4802        4802  China Spent  147 billion To Halt Stock Market ...
# 4803        4803  From Five-and-a-Half-Year Low to Three-Month H...
# 4804        4804  Big B Invests in Fire Fighting Equipment Compa...
# 4805        4805  Moody s Trims India s Growth Forecast to 7  Th...
# 4806        4806      Sensex to Touch 32 200 by December 2015  Citi
# 4807        4807  Can Sensex Gain from The Slump in Chinese Stoc...
# 4808        4808  Sensex May Fall by Over 2 000 Points in Next 3...
# 4809        4809  Gold Prices May See Free Fall on US Fed Rate Hike
# 4810        4810     Gold Prices May Plunge to Rs 23 000 in a Month
# 4811        4811  Rajesh Exports Buys 100  Stake in World s Larg...
# 4812        4812  ASUS Zenfone 2 First Impression  A Well Config...
# 4809  http://www.ibtimes.co.in/gold-prices-may-see-f...
# 4810                                                NaN
# 4811                                                NaN
# 4812  http://www.ibtimes.co.in/asus-zenfone-2-first-...
# 4813  http://www.ibtimes.co.in/lenovo-a7000-vs-asus-...
# 4814  http://www.ibtimes.co.in/asus-zenfone-2-releas...
# 4815                                                NaN
# 4816  http://www.ibtimes.co.in/did-you-know-moto-g-m...
# 4817  http://www.ibtimes.co.in/six-essential-securit...
# 4818  http://www.ibtimes.co.in/top-10-smartphones-ga...
# 4819                                                NaN
# 4820  http://www.ibtimes.co.in/top-six-3d-printing-d...
# 4821  http://www.ibtimes.co.in/mobile-world-congress...
# 4822  http://www.ibtimes.co.in/samsung-galaxy-s6-gal...
# 4823  http://www.ibtimes.co.in/htc-one-m9-plus-leaks...
# 4824  http://www.ibtimes.co.in/samsung-galaxy-s6-s6-...
# 4825  http://www.ibtimes.co.in/iphone-6-vs-samsung-g...
# 4826  http://www.ibtimes.co.in/samsung-galaxy-s6-vs-...
# 4827  http://www.ibtimes.co.in/htc-latest-octa-core-...
# 4828  http://www.ibtimes.co.in/samsung-galaxy-s6-act...
# 4829  http://www.ibtimes.co.in/google-rolls-out-andr...
# 4830                                                NaN
#
# [4831 rows x 6 columns]

# %%
#Articles to list
artlist = inputfile1['Content'].tolist()

# %%
#Saving the list of articles as pickle file
pk.dump(artlist,open("artlist.pkl","wb+"))

# %% [markdown]
# ## 3. Data preprocessing
#
# Data Preprocssing includes cleaning the data(removing punctuations and stopwords), tokenising, stemming, and vectorising the articles

# %%
def tokenizer_func(doc):
    #Function for tokenizing
    #removing punctuations
    doc1 = re.sub('[^\w_\s-]', ' ',doc)
    #Tokeninsing
    tokens = nltk.word_tokenize(doc1)
    #For stemming
    stems = [stemmer.stem(item) for item in tokens]
    return stems

# %%
def vectorizing(documents):
    #Function for vectorizing
    vectorizer = TfidfVectorizer(stop_words='english', min_df=2,
                                 tokenizer=tokenizer_func)
    X_data = vectorizer.fit_transform(documents)
    return X_data

# %%
def user_articles(article_ids,doc):
    #Function for combining input articles
    sen = ' '.join([doc[int(i)] for i in article_ids])
    doc.append(sen)
    return doc

# %% [markdown]
# ## 4. Similarity match
#
# Calculating the Cosine similarity between articles read and unread articles

# %%
def similarity(articles_id,tf_idf):
    #Function to calculate cosine similarity
    cs_matrix=cosine_similarity(tf_idf[-1], tf_idf)
    recommended_articles_id = numpy.concatenate(cs_matrix, axis=0).argsort()[:][::-1]
    #Remove read articles from recommendations
    final_recommended_articles_id = [art_id for art_id in recommended_articles_id 
                                     if art_id not in articles_id ][:5]
    return final_recommended_articles_id

# %%
#Reading the documents
documents = pk.load(open('artlist.pkl', 'rb+'))
articles_ids = [2,3]

# %%
#For combining the articles
new_art = user_articles(articles_ids,documents)
#For calculating the tf-idf vector
tf_idf = vectorizing(new_art)
#Recommendations
recommendations = similarity(articles_ids,tf_idf)

# %% [markdown]
# ## 5. Results

# %%
#Recommended Articles and their title
#df_news = pd.read_csv(PATH_NEWS_ARTICLES)
print 'Articles Read'
print inputfile1.loc[inputfile1['Article_Id'].isin(articles_ids)]['Title']
print '\n'
print 'Recommender '
print inputfile1.loc[inputfile1['Article_Id'].isin(recommendations)]['Title']
